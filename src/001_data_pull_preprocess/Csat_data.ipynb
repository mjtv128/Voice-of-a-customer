# %%
import numpy as np
import pandas as pd
import scipy as scs
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
import os
import datetime as dt

pd.set_option("display.max_columns", None)

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.cloud import bigquery
proj_name = 'pg-duke-student-capstone-v1'
proj_num = '545682952716'
proj_id = 'pg-duke-student-capstone-v1'
client = bigquery.Client(project=proj_id)

# %% [markdown]
# ### Importing the CSAT DATA

# %%
sql_query_csat = ('''SELECT *
                FROM pg-duke-student-capstone-v1.source_data.fact_csat
                ''')

# %%
df_csat = client.query(sql_query_csat).to_dataframe()

# %%
df_csat.head()
df_csat.shape
# Out:
# (6372, 20)

# %%
# browsing the data
df_csat.head()
# Out:
#    response_id            name                        email  score  \
# 0     86944680    James Lawson     recordarchives@yahoo.com    1.0
# 1    133149867   Stanley Vigil     avigilstanley@reagan.com    1.0
# 2    176595914  Anthony Spicer     tonyspicer1966@yahoo.com    2.0
# 3    156203539   Helen Present          presentpt@gmail.com    1.0
# 4    161881765            None  beachykeenrentals@gmail.com    4.0
#
#                                              comment  \
# 0  You ignored all of my emails.  If you're going...
# 1                                               None
# 2                                               None
# 3  Was looking for instant estimates and did not ...
# 4                                               None
#
#          response_timestamp notes  tags additional_question  application_id  \
# 0 2019-05-21 06:12:12+00:00  None  None                None         1500545
# 1 2020-07-07 23:00:28+00:00  None  None                None         2696137
# 2 2021-06-12 14:16:27+00:00  None  None                None         4014257
# 3 2020-12-20 13:11:35+00:00  None  None                None         3279081
# 4 2021-02-08 12:27:23+00:00  None  None                None         3510361
#
#   assignee_name                 conversation_id  customer_id browser  \
# 0          None  9bc56e88-1474-4b82-87fc-16b855     14750405  Chrome
# 1          None  bb80fa5e-1af7-4955-93fb-e017ee     31533636  Chrome
# 2          None  05bd4b09-15c8-43a1-9eb0-91d025     48531364  Chrome
# 3          None  e5ffb75c-1a8b-4d40-9f92-ff6b78     37792405  Safari
# 4          None  71da4556-eb6a-4f26-97d8-9a9474     41155353  Safari
#
#   device_type       os source internal_case_tags  \
# 0     Desktop  Windows  Email               None
# 1     Desktop  Windows  Email               None
# 2     Desktop  Windows  Email               None
# 3     Desktop      Mac  Email               None
# 4     Desktop      Mac  Email               None
#
#   lifecycle_stage_prior_to_withdrawn withdrawn_lifecycle_stage
# 0                               fake                 withdrawn
# 1                               fake                 withdrawn
# 2                               fake                 withdrawn
# 3                               fake                 withdrawn
# 4                               fake                 withdrawn

# %%
# we have 20 columns
df_csat.columns
# Out:
# Index(['response_id', 'name', 'email', 'score', 'comment',
#        'response_timestamp', 'notes', 'tags', 'additional_question',
#        'application_id', 'assignee_name', 'conversation_id', 'customer_id',
#        'browser', 'device_type', 'os', 'source', 'internal_case_tags',
#        'lifecycle_stage_prior_to_withdrawn', 'withdrawn_lifecycle_stage'],
#       dtype='object')

# %%
# Application id looks fine, we don't seem to have product type here
df_csat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6372 entries, 0 to 6371
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   response_id                         6372 non-null   int64
#  1   name                                5991 non-null   object
#  2   email                               6372 non-null   object
#  3   score                               6372 non-null   float64
#  4   comment                             3486 non-null   object
#  5   response_timestamp                  6372 non-null   datetime64[ns, UTC]
#  6   notes                               0 non-null      object
#  7   tags                                0 non-null      object
#  8   additional_question                 0 non-null      object
#  9   application_id                      6372 non-null   int64
#  10  assignee_name                       0 non-null      object
#  11  conversation_id                     6372 non-null   object
#  12  customer_id                         6372 non-null   int64
#  13  browser                             6372 non-null   object
#  14  device_type                         6372 non-null   object
#  15  os                                  6372 non-null   object
#  16  source                              6372 non-null   object
#  17  internal_case_tags                  0 non-null      object
#  18  lifecycle_stage_prior_to_withdrawn  6372 non-null   object
#  19  withdrawn_lifecycle_stage           6372 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(3), object(15)
# memory usage: 995.8+ KB

# %%
## 
df_csat.lifecycle_stage_prior_to_withdrawn.value_counts()
# Out:
# application_requested                          2676
# sign_and_exam                                  1724
# application_in_underwriting                     541
# application_not_started                         493
# aps_ordered                                     305
# contact_info_submitted_online                   295
# application_started_by_client                   141
# application_in_underwriting_tentative_offer      56
# application_declined                             28
# fake                                             24
# application_approved_with_modifications          20
# policy_rejected                                  14
# policy_offer_postponed                           12
# application_approved_as_applied                  11
# phone_screen_decline                              8
# policy_sent_to_client                             5
# application_pending_client                        5
# case_closed_incomplete                            4
# application_in_underwriting_final_review          3
# policy_in_force                                   2
# policy_delivery_reqs_received                     2
# merged                                            1
# policy_offer_modified_reissued                    1
# underwriting_application_closed_withdrawn         1
# Name: lifecycle_stage_prior_to_withdrawn, dtype: int64

# %%
## checking duplicates in application id [No dupliactes in application_id]

df_csat.loc[df_csat.duplicated(keep=False)].sort_values(by="application_id")
# Out:
# Empty DataFrame
# Columns: [response_id, name, email, score, comment, response_timestamp, notes, tags, additional_question, application_id, assignee_name, conversation_id, customer_id, browser, device_type, os, source, internal_case_tags, lifecycle_stage_prior_to_withdrawn, withdrawn_lifecycle_stage]
# Index: []

# %%
df_csat.columns
# Out:
# Index(['response_id', 'name', 'email', 'score', 'comment',
#        'response_timestamp', 'notes', 'tags', 'additional_question',
#        'application_id', 'assignee_name', 'conversation_id', 'customer_id',
#        'browser', 'device_type', 'os', 'source', 'internal_case_tags',
#        'lifecycle_stage_prior_to_withdrawn', 'withdrawn_lifecycle_stage'],
#       dtype='object')

# %%
## reordering columns so that ids appear first

columnsTitles = ['application_id', 'response_id', 'response_timestamp', 'customer_id', 'conversation_id','name', 'email', 'score', 'comment', 'notes','tags', \
                 'additional_question', 'assignee_name', 'device_type', 'browser', 'os', 'source','internal_case_tags','lifecycle_stage_prior_to_withdrawn', \
                 'withdrawn_lifecycle_stage']
df_csat = df_csat.reindex(columns=columnsTitles)
df_csat.head()
# Out:
#    application_id  response_id        response_timestamp  customer_id  \
# 0         1500545     86944680 2019-05-21 06:12:12+00:00     14750405
# 1         2696137    133149867 2020-07-07 23:00:28+00:00     31533636
# 2         4014257    176595914 2021-06-12 14:16:27+00:00     48531364
# 3         3279081    156203539 2020-12-20 13:11:35+00:00     37792405
# 4         3510361    161881765 2021-02-08 12:27:23+00:00     41155353
#
#                   conversation_id            name  \
# 0  9bc56e88-1474-4b82-87fc-16b855    James Lawson
# 1  bb80fa5e-1af7-4955-93fb-e017ee   Stanley Vigil
# 2  05bd4b09-15c8-43a1-9eb0-91d025  Anthony Spicer
# 3  e5ffb75c-1a8b-4d40-9f92-ff6b78   Helen Present
# 4  71da4556-eb6a-4f26-97d8-9a9474            None
#
#                          email  score  \
# 0     recordarchives@yahoo.com    1.0
# 1     avigilstanley@reagan.com    1.0
# 2     tonyspicer1966@yahoo.com    2.0
# 3          presentpt@gmail.com    1.0
# 4  beachykeenrentals@gmail.com    4.0
#
#                                              comment notes  tags  \
# 0  You ignored all of my emails.  If you're going...  None  None
# 1                                               None  None  None
# 2                                               None  None  None
# 3  Was looking for instant estimates and did not ...  None  None
# 4                                               None  None  None
#
#   additional_question assignee_name device_type browser       os source  \
# 0                None          None     Desktop  Chrome  Windows  Email
# 1                None          None     Desktop  Chrome  Windows  Email
# 2                None          None     Desktop  Chrome  Windows  Email
# 3                None          None     Desktop  Safari      Mac  Email
# 4                None          None     Desktop  Safari      Mac  Email
#
#   internal_case_tags lifecycle_stage_prior_to_withdrawn  \
# 0               None                               fake
# 1               None                               fake
# 2               None                               fake
# 3               None                               fake
# 4               None                               fake
#
#   withdrawn_lifecycle_stage
# 0                 withdrawn
# 1                 withdrawn
# 2                 withdrawn
# 3                 withdrawn
# 4                 withdrawn

# %%
## check duplicates in other ids [No other ids are duplicated]

df_csat.loc[df_csat.duplicated("response_timestamp", keep=False)].sort_values("response_timestamp").head(10)
# Out:
# Empty DataFrame
# Columns: [application_id, response_id, response_timestamp, customer_id, conversation_id, name, email, score, comment, notes, tags, additional_question, assignee_name, device_type, browser, os, source, internal_case_tags, lifecycle_stage_prior_to_withdrawn, withdrawn_lifecycle_stage]
# Index: []

# %%
## checking for any missing data [if comment is the equivalent of verbatim then we may throw away 45.3% of data]
missing = pd.DataFrame({"percent_missing" : df_csat.isna().sum()*100/len(df_csat)})
missing
# Out:
#                                     percent_missing
# application_id                             0.000000
# response_id                                0.000000
# response_timestamp                         0.000000
# customer_id                                0.000000
# conversation_id                            0.000000
# name                                       5.979284
# email                                      0.000000
# score                                      0.000000
# comment                                   45.291902
# notes                                    100.000000
# tags                                     100.000000
# additional_question                      100.000000
# assignee_name                            100.000000
# device_type                                0.000000
# browser                                    0.000000
# os                                         0.000000
# source                                     0.000000
# internal_case_tags                       100.000000
# lifecycle_stage_prior_to_withdrawn         0.000000
# withdrawn_lifecycle_stage                  0.000000

# %%
### Final CSTAT DATA
df_csat.shape
# Out:
# (6372, 20)

# %%
## save the data in CSV 
#df_csat.to_csv (r'C:\Users\Ron\Desktop\export_dataframe.csv', index = False, header=True)
df_csat.to_csv('df_csat.csv')
#print (df_csat)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
