# %% [markdown]
# # BERTopic for detractors

# %%
# Importing necessary libraries/packages
import numpy as np
import pandas as pd
import scipy as scs
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
import os
import datetime as dt
import re

import gensim
from gensim.utils import simple_preprocess
import nltk

import gensim.corpora as corpora
from pprint import pprint

#import pyLDAvis.gensim_models
import pickle 
#import pyLDAvis

pd.set_option("display.max_columns", 50, "display.max_rows", 100)

# Authentication
from google.colab import auth
auth.authenticate_user()

#Importing data from bigquery
from google.cloud import bigquery
proj_name = 'pg-duke-student-capstone-v1'
proj_num = '545682952716'
proj_id =   'pg-duke-student-capstone-v1'
client = bigquery.Client(project=proj_id)

# !pip install contractions
### Importing necessary libraries
import pandas as pd
import nltk
import string
#stopwords
from nltk.corpus import stopwords
#tokenizer
from nltk.tokenize import RegexpTokenizer
#lemmatizer
from nltk.stem import WordNetLemmatizer
#Stemmer
from nltk.stem.porter import PorterStemmer

#contractions
import contractions

#gensims
import gensim
from gensim import models
from gensim.utils import simple_preprocess
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# !pip install bertopic
from bertopic import BERTopic
# !pip install joblib==1.1.0

from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic import BERTopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting pyahocorasick
#   Downloading pyahocorasick-2.0.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 1.4 MB/s eta 0:00:00
# Collecting anyascii
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 4.0 MB/s eta 0:00:00
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/hdbscan/
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 23.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 80.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.2 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.2 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3580437 sha256=6357657012002605e692a247a3d018c21fffed8aa40586b1e332dd7238dba2f6
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=aa4b35ab49eb93d6c38cbdc51fb540871fdc3200085e541f1d06784d01955bcd
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=22e70c495f3ca435ddd700c0868cec63d652aeab24b92759808b8c0069644e6c
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55509 sha256=1a79bb433e31c0d55bd4a58abfa8f9d81e1d62ecd3cbf70f0810a25c771cc20a
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.13.4 pynndescent-0.5.8 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.27.4 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joblib==1.1.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.2.2 requires joblib>=1.1.1, but you have joblib 1.1.0 which is incompatible.
# imbalanced-learn 0.10.1 requires joblib>=1.1.1, but you have joblib 1.1.0 which is incompatible.
# Successfully installed joblib-1.1.0

# %% [markdown]
# Load Data

# %%
# Reading data from big query

sql_query_csat = ('''SELECT *
                FROM pg-duke-student-capstone-v1.final_merged.clean_nps
                ''')

# Run a Standard SQL query with the project set explicitly
project_id = 'pg-duke-student-capstone-v1'
#data = pd.read_gbq(sql, project_id=project_id, dialect='standard')
data = pd.read_gbq(sql_query_csat, project_id=proj_id, dialect='standard')
data.head()
# Out:
#    int64_field_0  application_id product_type  respondent_id  \
# 0            905       1273719.0  homeandauto      962841204
# 1           1380        428727.0  homeandauto      669663712
# 2           1389        841048.0  homeandauto      850431113
# 3           1398       1454888.0  homeandauto     1047155544
# 4           1419       1544133.0  homeandauto     1075912288
#
#                          survey_key                created_at  score  \
# 0  KEv4iDf9fOwFkrqGJ3dG78E3FXmoEjs5 2021-10-04 14:04:10+00:00     10
# 1  a9CaYMZQJ6YAxihgHTyWSD1DhpTxGb9I 2020-07-24 14:09:47+00:00      8
# 2  o9BFKWnnOducRd4AjQcETyjbHbTj0xQb 2021-04-02 16:57:16+00:00      9
# 3  BHUlqVZW1c5am64nlz3rXnnJop68iqXS 2022-01-06 13:03:58+00:00     10
# 4  qSi8fsNFAjS3atrE54cmsd52Mec8gsmP 2022-02-17 11:47:16+00:00     10
#
#   zendesk_ticket_id medium                                           verbatim  \
# 0              None   None                                Listen to problems
# 1              None   None  My experience with Policy genius was great and...
# 2              None   None  Working with you was fast and easy and I like ...
# 3              None   None  My agent was very informed and help make the p...
# 4              None   None  I got my insurance for both vehicles cut in ha...
#
#                   analytics_user_id               analytics_user_id_1  gender  \
# 0  1ae9467c575a4697bd99382cb7901979  1ae9467c575a4697bd99382cb7901979    male
# 1  6dfe7167d4c741cca83826dc5b22c580  6dfe7167d4c741cca83826dc5b22c580  female
# 2  2f359d6cde594f309b0989e96ce2454f  2f359d6cde594f309b0989e96ce2454f    male
# 3  052feaa8c2a14c94953481e4c0567dd3  052feaa8c2a14c94953481e4c0567dd3    male
# 4  653fc046465e40dc8b3b0f73a17bdcfd  653fc046465e40dc8b3b0f73a17bdcfd    male
#
#   state_code  individual_income   age marketing_application_source  \
# 0       None                NaN  77.0                       Direct
# 1       None                NaN  37.0                       Direct
# 2         WI                NaN  56.0                       Direct
# 3         CA                NaN  28.0                       Direct
# 4         LA                NaN  35.0                       Direct
#
#   first_touch_device  bmi  num_conditions  history_of_tobacco_use  \
# 0            Desktop  NaN             0.0                    <NA>
# 1            Desktop  NaN             0.0                    <NA>
# 2            Desktop  NaN             0.0                    <NA>
# 3            Desktop  NaN             0.0                    <NA>
# 4            Desktop  NaN             0.0                    <NA>
#
#   marital_status  segment segment_description
# 0       divorced      NaN                None
# 1           None      NaN                None
# 2         single      NaN                None
# 3        married      NaN                None
# 4        married      NaN                None

# %% [markdown]
# # Pre-processing

# %% [markdown]
# Create Data time variables and separated the data into detractors, passives, and promoters

# %%
data = data.dropna(subset=["verbatim"], axis=0)

data['date'] = pd.to_datetime(data['created_at'])
data['day'] = data['date'].dt.day
data['month'] = data['date'].dt.month
data['year'] = data['date'].dt.year

data["score_categorized"] = pd.cut(data.score, bins=[-np.inf, 6, 8, 10],
                  labels=["detractor", "passive", "promoter"])

det = data[data['score_categorized'] == 'detractor']
det["year-month"] =det.year.astype(str) + "-" + det.month.astype(str)
det_nps = det["verbatim"].tolist()
det_nps_1 = "".join(det_nps)
det["verbatim_len"] = det["verbatim"].apply(lambda x : len(x.split()))
det_arr = np.array(det["verbatim"])

years = [2017, 2018, 2019, 2020, 2021, 2022]
for year in years:
   globals()[f'det_{year}'] = det[det['year'] == year]

# %% [markdown]
# Preprocessing steps including normalizing, tokenising, removing stopwords, punctuations etc

# %%
#DATA PREPROCESSING STEPS
### Removing stopwords, tokenizing data, lemmaziting, converting to lower case, remove panctuations, i 

stop_words = stopwords.words('english')

stop_words.extend(['from', 'subject', 'use', 'policygenius', 'policy', 'genius','insurance', "pg", 'none', 'na', "able", "already", "also",
                   "was", "were", "thus", "although", "always", "bc", "because", "definitely", "could", "couldnt", 'would', "wouldnt"])

def preprocess(text_col):
    """This function will apply NLP preprocessing lambda functions over a pandas series such as df['text'].
       These functions include converting text to lowercase, removing emojis, expanding contractions, removing punctuation,
       removing numbers, removing stopwords, lemmatization, etc."""
    
    # convert to lowercase
    text_col = text_col.apply(lambda x: ' '.join([w.lower() for w in x.split('/')]))
    
    # remove emojis
    #text_col = text_col.apply(lambda x: demoji.replace(x, ""))
    
    # expand contractions  
    text_col = text_col.apply(lambda x: ' '.join([contractions.fix(word) for word in x.split()]))

    # remove punctuation
    text_col = text_col.apply(lambda x: ''.join([i for i in x if i not in string.punctuation]))
    
    # remove numbers
    text_col = text_col.apply(lambda x: ' '.join(re.sub("[^a-zA-Z]+", " ", x).split()))

    # remove stopwords
    stopwords = [sw for sw in stop_words if sw not in ['not', 'no']]
    text_col = text_col.apply(lambda x: ' '.join([w for w in x.split() if w not in stopwords]))

    # lemmatization
    from nltk.stem import WordNetLemmatizer
    nltk.download('wordnet')
    nltk.download('omw-1.4')
    text_col = text_col.apply(lambda x: ' '.join([WordNetLemmatizer().lemmatize(w) for w in x.split()]))

    # stemming
    #from nltk.stem import PorterStemmer
    #text_col = text_col.apply(lambda x: ' '.join([PorterStemmer().stem(w) for w in x.split()]))

    # remove short words
    text_col = text_col.apply(lambda x: ' '.join([w.strip() for w in x.split() if len(w.strip()) >= 3]))

    return text_col

# %% [markdown]
# Preprocessing the detractors dataset

# %%
det_clean = preprocess(det["verbatim"])  #[3] # L + stemming

det_clean = preprocess(det["verbatim"])  #[3] # L + stemming
det_clean1 = np.array(det_clean)   
# det_clean1
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # Modelling + Fine-tuning

# %% [markdown]
# Fine-tuning each step of Bertopic

# %%
## Defining the different steps the Bertopic algorithm uses to process and analyse the data

# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Step 2 - Reduce dimensionality
umap_model = UMAP(random_state=1832,n_neighbors=40, n_components=8, min_dist=0.0, metric='cosine') # n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine'

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=40, min_samples=1, metric='euclidean', cluster_selection_method='eom', prediction_data = True) # min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True

# Step 4 - Tokenize topics and create ngrams
vectorizer_model = CountVectorizer(stop_words="english", ngram_range= (2, 3))

# Step 5 - Create topic representation 
ctfidf_model = ClassTfidfTransformer()

# %%
# Putting All steps together nr_topics=7

topic_model_detra = BERTopic(nr_topics= 6, 
  embedding_model=embedding_model,    # Step 1 - Extract embeddings
  umap_model=umap_model,              # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,        # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,  # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model, verbose = True)          # Step 5 - Extract topic words
  #diversity=0.8)                       # Step 6 - Diversify topic words)

topics, probs = topic_model_detra.fit_transform(det_clean1)
# Out:
# Batches:   0%|          | 0/28 [00:00<?, ?it/s]
# 2023-04-13 01:05:46,036 - BERTopic - Transformed documents to Embeddings
# 2023-04-13 01:05:51,036 - BERTopic - Reduced dimensionality
# 2023-04-13 01:05:51,087 - BERTopic - Clustered reduced embeddings
# 2023-04-13 01:05:54,267 - BERTopic - Reduced number of topics from 10 to 6

# %%
from bertopic import BERTopic
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

#topic_model = BERTopic(verbose=True, n_gram_range=(1, 3))
#topics, _ = topic_model.fit_transform(docs)

# Preprocess Documents
documents = pd.DataFrame({"Document": det_clean1,
                          "ID": range(len(det_clean1)),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document':' '.join})
cleaned_docs = topic_model_detra._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = topic_model_detra.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model_detra.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Removing any empty strings
topic_words = [[x for x in sub_arr if x not in ('', None)] for sub_arr in topic_words]
topic_words


# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence = coherence_model.get_coherence()
print(coherence)
# Out:
# 0.6202549099827539

# %%
topic_model_detra.get_topic_info()
# Out:
#    Topic  Count                                               Name
# 0     -1    229  -1_took month_customer service_process took_fe...
# 1      0    235  0_took month_process took_medical record_way long
# 2      1    180  1_customer service_felt like_bait switch_custo...
# 3      2    141    2_text email_phone email_email text_email phone
# 4      3     49  3_lack communication_response communication_sl...
# 5      4     46  4_took month_half birthday_account debited_pay...

# %%
# topic_model_detra.save('/content/det_model')

# %%
words_df = pd.DataFrame({'topics': topics, 'doc_cleaned': det_clean1, 'doc_raw': det['verbatim']})

# %%
words_df[words_df['topics'] == 4]
# Out:
#        topics                                        doc_cleaned  \
# 74          4                                    turned coverage
# 255         4  fairly simple process sign not allow much cove...
# 311         4  completely botching start date application pay...
# 441         4  requested clear wanted oneyear longterm disabi...
# 2267        4  application insurer website long call answer l...
# 2345        4  found process drawn think gone directly insure...
# 2433        4  went month without coverageno communication un...
# 2529        4  found experience relatively painfree cannot re...
# 2585        4  seems communication insuring company still not...
# 3062        4  happy process except not read paid agent spoke...
# 3716        4  sheryl great comfortable way payment due sugge...
# 4000        4  process nightmare took month get health check ...
# 5053        4  agent not disclose back pay three month entere...
# 5124        4  take absolutely long get underwriting banner l...
# 5412        4  took close get much easier banner directly sin...
# 5448        4  information flow one way bank account debited ...
# 5658        4  reason not giving higher score long took final...
# 6491        4  feel like suckered picking insurer going make ...
# 6894        4  maybe missed nuance front end understood gap c...
# 6919        4  took month get policystarted way birthdayit ca...
# 7341        4  impersonal spend money printing page copy safe...
# 8136        4  process slow applied life december date still ...
# 8430        4  process quick easy however misinformed coverag...
# 8873        4         coverage sent home not match one purchased
# 9044        4  got bill health screening required switching j...
# 9056        4  not take week get approved timing suspect fina...
# 9105        4  checking account debited gave explicit approva...
# 9320        4  first quoted month took month finalize asked p...
# 9321        4  misinformation temporary coverage poor executi...
# 9402        4                            took month get coverage
# 9636        4  process get coverage lengthy almost two month ...
# 9673        4  like genius initial access multiple quote diff...
# 9869        4  completed life application january march compl...
# 10064       4  time application issue excessive month caused ...
# 10214       4                    charged three month noncoverage
# 10420       4  took way long place staff not knowledgeable in...
# 10744       4  one health category changed based wrong weight...
# 11532       4  billing cycle implemented not chose digital re...
# 11877       4  final sign step payment poorly coordinated aig...
# 12191       4  took month process claim never told passed hal...
# 12337       4  slowit took month get insured due multiple rea...
# 12479       4  medical exam company assured managed make huge...
# 12480       4  took long time month not asked whether interim...
# 12792       4  process finding providing family life coverage...
# 12828       4  wish guidance choosing right coverage instead ...
# 13055       4  started process april not get accepted july ev...
#
#                                                  doc_raw
# 74                       You turned me down for coverage
# 255    It was a fairly simple process to sign up for ...
# 311    completely botching up the start date of my ap...
# 441    I requested and was very clear that I wanted a...
# 2267   Most of the application was on the insurers we...
# 2345   We found the process very drawn out. I think I...
# 2433   I went 6 months without coverageNo communicati...
# 2529   While I found the experience relatively pain-f...
# 2585   There seems to be no communication between you...
# 3062   I’m happy with my policy and the process. Exce...
# 3716   Sheryl was great and was comfortable all the w...
# 4000   The process was a nightmare.  It took 3 months...
# 5053   The agent did not disclose that I would have t...
# 5124   Takes absolutely too long to get a policy thro...
# 5412   Took close to 4 1/2 to get a policy. Would of ...
# 5448   The information flow has been one way. My bank...
# 5658   The reason I’m not giving a higher score is be...
# 6491   Feel like I was suckered into picking an insur...
# 6894   Maybe I missed the nuance on the front end and...
# 6919   It took 9 months to get this policy...started ...
# 7341   Impersonal, I had to spend my own money printi...
# 8136   The process is very slow. I applied for life i...
# 8430   The process was quick and easy. However, I was...
# 8873   Coverage policy sent home does not match the o...
# 9044   I got a bill for $900 for a health screening t...
# 9056   It should not take 12 weeks to get approved. T...
# 9105   My checking account was debited before I gave ...
# 9320   First I was quoted $96/month, but because it t...
# 9321   The misinformation about the temporary coverag...
# 9402            It took over 7 months to get my coverage
# 9636   The process to get insurance coverage is very ...
# 9673   I like Policy Genius's initial access to multi...
# 9869   I completed my Life Insurance application in J...
# 10064  Time from application to policy issue was exce...
# 10214  You charged me for three months of non-coverage.
# 10420  Policy took way to long to place and staff wer...
# 10744  On one policy, health category was changed bas...
# 11532  The billing cycle implemented was not what I c...
# 11877  Final sign up steps and payment was poorly coo...
# 12191  it took 7 months to process my claim - was nev...
# 12337  Too slowIt took me 5+ months to get insured du...
# 12479  The medical exam company assured by you manage...
# 12480  It took a very long time, more than 3 months, ...
# 12792  The process of finding and providing my family...
# 12828  I wish there had been more guidance in how to ...
# 13055  We started the process in April and couldn’t g...

# %% [markdown]
# Reduces outliers

# %%
new_topics = topic_model_detra.reduce_outliers(det_clean1, topics, probabilities=probs)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 17.64it/s]

# %% [markdown]
# Creating a table consisting of detractor key themes and raw comments for Tableau dashboard

# %%
tbl1 = pd.DataFrame({'topic': new_topics, 'doc_cleaned': det_clean1, 'raw comment': det["verbatim"], 
                            'year': det['year'],
                            'year-month': det['year-month']})

# %%
tbl1.topic.value_counts()
# Out:
#  0    302
#  1    228
#  2    185
#  3     60
#  4     57
# -1     48
# Name: topic, dtype: int64

# %%
doc_info = topic_model_detra.get_document_info(det_clean1)
doc_info.head()
# Out:
#                                             Document  Topic  \
# 0  web site faulty not update progress correctly ...     -1
# 1  ask question over secure web site difficult ac...     -1
# 2  first time heard need little time recommend fa...      1
# 3                                    turned coverage      4
# 4                                      friend family      1
#
#                                                 Name  \
# 0  -1_took month_customer service_process took_fe...
# 1  -1_took month_customer service_process took_fe...
# 2  1_customer service_felt like_bait switch_custo...
# 3  4_took month_half birthday_account debited_pay...
# 4  1_customer service_felt like_bait switch_custo...
#
#                                          Top_n_words  Probability  \
# 0  took month - customer service - process took -...          0.0
# 1  took month - customer service - process took -...          0.0
# 2  customer service - felt like - bait switch - c...          1.0
# 3  took month - half birthday - account debited -...          1.0
# 4  customer service - felt like - bait switch - c...          1.0
#
#    Representative_document
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
topic_model_detra.get_topic_info()
# Out:
#    Topic  Count                                               Name
# 0     -1    229  -1_took month_customer service_process took_fe...
# 1      0    235  0_took month_process took_medical record_way long
# 2      1    180  1_customer service_felt like_bait switch_custo...
# 3      2    141    2_text email_phone email_email text_email phone
# 4      3     49  3_lack communication_response communication_sl...
# 5      4     46  4_took month_half birthday_account debited_pay...

# %%
doc_info[doc_info['Topic'] == 4]['Top_n_words'].value_counts()
# Out:
# took month - half birthday - account debited - payment info - month finalize - fault company - pay higher - payment date - interim coverage - coverage took    46
# Name: Top_n_words, dtype: int64

# %%
det_tbl = pd.DataFrame({'comment': det.verbatim, 
                            'group': det.score_categorized, 
                            'topic': new_topics, 
                            'top_n_words': doc_info.Top_n_words.values,
                            'date': det.date})

# %%
det_tbl.head()
# Out:
#                                               comment      group  topic  \
# 27  Web site faulty didn't update with progress co...  detractor      1
# 31  You ask the the same questions overs and over....  detractor      1
# 64  First time i heard about Policygenius, need a ...  detractor      1
# 74                    You turned me down for coverage  detractor      4
# 84                        I have no friends or family  detractor      1
#
#                                           top_n_words  \
# 27  took month - customer service - process took -...
# 31  took month - customer service - process took -...
# 64  customer service - felt like - bait switch - c...
# 74  took month - half birthday - account debited -...
# 84  customer service - felt like - bait switch - c...
#
#                         date
# 27 2017-05-23 15:56:31+00:00
# 31 2022-04-01 12:03:30+00:00
# 64 2020-11-03 16:50:35+00:00
# 74 2020-11-12 14:23:14+00:00
# 84 2021-11-18 17:33:55+00:00

# %%
det_tbl[det_tbl['topic'] == 1]
# Out:
#                                                  comment      group  topic  \
# 27     Web site faulty didn't update with progress co...  detractor      1
# 31     You ask the the same questions overs and over....  detractor      1
# 64     First time i heard about Policygenius, need a ...  detractor      1
# 84                           I have no friends or family  detractor      1
# 117                                              It’s ok  detractor      1
# ...                                                  ...        ...    ...
# 13023  Didn't like getting bounced around to differen...  detractor      1
# 13076  I had 4 different “agents” minor of whom took ...  detractor      1
# 13127  Given the overall timeline, buying life insura...  detractor      1
# 13135  I felt like i did more of this than policygeni...  detractor      1
# 13163  didn't really find it to be any easier than go...  detractor      1
#
#                                              top_n_words  \
# 27     customer service - felt like - bait switch - c...
# 31     customer service - felt like - bait switch - c...
# 64     customer service - felt like - bait switch - c...
# 84     customer service - felt like - bait switch - c...
# 117    customer service - felt like - bait switch - c...
# ...                                                  ...
# 13023  customer service - felt like - bait switch - c...
# 13076  customer service - felt like - bait switch - c...
# 13127  customer service - felt like - bait switch - c...
# 13135  customer service - felt like - bait switch - c...
# 13163  customer service - felt like - bait switch - c...
#
#                            date
# 27    2017-05-23 15:56:31+00:00
# 31    2022-04-01 12:03:30+00:00
# 64    2020-11-03 16:50:35+00:00
# 84    2021-11-18 17:33:55+00:00
# 117   2022-03-26 11:13:22+00:00
# ...                         ...
# 13023 2021-10-14 11:46:15+00:00
# 13076 2018-06-04 09:06:05+00:00
# 13127 2020-09-28 10:51:36+00:00
# 13135 2022-02-15 18:49:04+00:00
# 13163 2019-05-09 12:40:57+00:00
#
# [228 rows x 5 columns]

# %%
det_tbl.top_n_words.value_counts()
# Out:
# quote - email - agent - good - phone - time - coverage - communication - easy - process - service - company - great - like - recommend                                                                302
# good - service - experience - great - easy - good service - customer - good experience - customer service - option - great service - best - rate - helpful - overall                                  228
# easy - process - easy process - quick - helpful - process easy - simple - ease - staff - work - response - quick easy - easy easy - convenient - fast                                                 185
# process - took - long - process took - longer - took longer - underwriting - process took longer - expected - took long - longer expected - long time - took longer expected - time - long process     60
# medical - exam - medical exam - record - process - professional - medical record - provider - issue - time - process medical - month - information - told - doctor                                     57
# took month - customer service - process took - felt like - took week - took long - entire process - process felt - feel like - long time                                                               48
# Name: top_n_words, dtype: int64

# %%
det_tbl.loc[det_tbl['topic'] == 0, 'top_n_words'] = 'took month - process took - medical record - way long - took long - took way - took way long - long process - pacific life - felt like'
det_tbl.loc[det_tbl['topic'] == 1, 'top_n_words'] = 'customer service - felt like - bait switch - customer experience - experience great - original quote - long time - initial quote - good experience - monthly premium'
det_tbl.loc[det_tbl['topic'] == 2, 'top_n_words'] = 'text email - phone email - email text - email phone - text message - received email - poor communication - pacific life - different people - multiple day'
det_tbl.loc[det_tbl['topic'] == 3, 'top_n_words'] = 'lack communication - response communication - slow response - communication lack - response time - slow response communication - delay processing - wait time - proper communication - poor communication'
det_tbl.loc[det_tbl['topic'] == 4, 'top_n_words'] = 'took month - half birthday - account debited - payment info - month finalize - fault company - pay higher - payment date - interim coverage - coverage took'

# %%
det_tbl.groupby(["topic", "top_n_words"]).count()
# Out:
#                                                           comment  group  date
# topic top_n_words
# -1    took month - customer service - process took - ...       48     48    48
#  0    took month - process took - medical record - wa...      302    302   302
#  1    customer service - felt like - bait switch - cu...      228    228   228
#  2    text email - phone email - email text - email p...      185    185   185
#  3    lack communication - response communication - s...       60     60    60
#  4    took month - half birthday - account debited - ...       57     57    57

# %%
topic_words_mapping = doc_info[["Topic", "Top_n_words"]].drop_duplicates().rename(columns={"Topic": "topic", "Top_n_words": "top_n_words"})

# %%
topic_words_mapping.set_index("topic").to_dict()["top_n_words"]
# Out:
# {-1: 'took month - customer service - process took - felt like - took week - took long - entire process - process felt - feel like - long time',
#  1: 'customer service - felt like - bait switch - customer experience - experience great - original quote - long time - initial quote - good experience - monthly premium',
#  4: 'took month - half birthday - account debited - payment info - month finalize - fault company - pay higher - payment date - interim coverage - coverage took',
#  0: 'took month - process took - medical record - way long - took long - took way - took way long - long process - pacific life - felt like',
#  3: 'lack communication - response communication - slow response - communication lack - response time - slow response communication - delay processing - wait time - proper communication - poor communication',
#  2: 'text email - phone email - email text - email phone - text message - received email - poor communication - pacific life - different people - multiple day'}

# %%
replaced_topnwords = det_tbl[["top_n_words"]].replace(topic_words_mapping)

# %%
det_tbl[det_tbl['topic'] == 1]
# Out:
#                                                  comment      group  topic  \
# 27     Web site faulty didn't update with progress co...  detractor      1
# 31     You ask the the same questions overs and over....  detractor      1
# 64     First time i heard about Policygenius, need a ...  detractor      1
# 84                           I have no friends or family  detractor      1
# 117                                              It’s ok  detractor      1
# ...                                                  ...        ...    ...
# 13023  Didn't like getting bounced around to differen...  detractor      1
# 13076  I had 4 different “agents” minor of whom took ...  detractor      1
# 13127  Given the overall timeline, buying life insura...  detractor      1
# 13135  I felt like i did more of this than policygeni...  detractor      1
# 13163  didn't really find it to be any easier than go...  detractor      1
#
#                                              top_n_words  \
# 27     customer service - felt like - bait switch - c...
# 31     customer service - felt like - bait switch - c...
# 64     customer service - felt like - bait switch - c...
# 84     customer service - felt like - bait switch - c...
# 117    customer service - felt like - bait switch - c...
# ...                                                  ...
# 13023  customer service - felt like - bait switch - c...
# 13076  customer service - felt like - bait switch - c...
# 13127  customer service - felt like - bait switch - c...
# 13135  customer service - felt like - bait switch - c...
# 13163  customer service - felt like - bait switch - c...
#
#                            date
# 27    2017-05-23 15:56:31+00:00
# 31    2022-04-01 12:03:30+00:00
# 64    2020-11-03 16:50:35+00:00
# 84    2021-11-18 17:33:55+00:00
# 117   2022-03-26 11:13:22+00:00
# ...                         ...
# 13023 2021-10-14 11:46:15+00:00
# 13076 2018-06-04 09:06:05+00:00
# 13127 2020-09-28 10:51:36+00:00
# 13135 2022-02-15 18:49:04+00:00
# 13163 2019-05-09 12:40:57+00:00
#
# [228 rows x 5 columns]

# %%
det_final = det_tbl.reset_index(drop=True)
det_final.head()
# Out:
#                                              comment      group  topic  \
# 0  Web site faulty didn't update with progress co...  detractor      1
# 1  You ask the the same questions overs and over....  detractor      1
# 2  First time i heard about Policygenius, need a ...  detractor      1
# 3                    You turned me down for coverage  detractor      4
# 4                        I have no friends or family  detractor      1
#
#                                          top_n_words  \
# 0  customer service - felt like - bait switch - c...
# 1  customer service - felt like - bait switch - c...
# 2  customer service - felt like - bait switch - c...
# 3  took month - half birthday - account debited -...
# 4  customer service - felt like - bait switch - c...
#
#                        date             topic_desc
# 0 2017-05-23 15:56:31+00:00        1 - High quotes
# 1 2022-04-01 12:03:30+00:00        1 - High quotes
# 2 2020-11-03 16:50:35+00:00        1 - High quotes
# 3 2020-11-12 14:23:14+00:00  4 - Poor organisation
# 4 2021-11-18 17:33:55+00:00        1 - High quotes

# %%
det_final['topic_desc'] = 'Outlier'
det_final.loc[det_final['topic'] == 0, 'topic_desc'] = '0 - Long processes'
det_final.loc[det_final['topic'] == 1, 'topic_desc'] = '1 - High quotes'
det_final.loc[det_final['topic'] == 2, 'topic_desc'] = '2 - Excessive contact'
det_final.loc[det_final['topic'] == 3, 'topic_desc'] = '3 - Poor communication'
det_final.loc[det_final['topic'] == 4, 'topic_desc'] = '4 - Poor organisation'

# %%
det_final.head()
# Out:
#                                              comment      group  topic  \
# 0  Web site faulty didn't update with progress co...  detractor      1
# 1  You ask the the same questions overs and over....  detractor      1
# 2  First time i heard about Policygenius, need a ...  detractor      1
# 3                    You turned me down for coverage  detractor      4
# 4                        I have no friends or family  detractor      1
#
#                                          top_n_words  \
# 0  customer service - felt like - bait switch - c...
# 1  customer service - felt like - bait switch - c...
# 2  customer service - felt like - bait switch - c...
# 3  took month - half birthday - account debited -...
# 4  customer service - felt like - bait switch - c...
#
#                        date             topic_desc
# 0 2017-05-23 15:56:31+00:00        1 - High quotes
# 1 2022-04-01 12:03:30+00:00        1 - High quotes
# 2 2020-11-03 16:50:35+00:00        1 - High quotes
# 3 2020-11-12 14:23:14+00:00  4 - Poor organisation
# 4 2021-11-18 17:33:55+00:00        1 - High quotes

# %%
det_final.topic_desc.value_counts()
# Out:
# 0 - Long processes        302
# 1 - High quotes           228
# 2 - Excessive contact     185
# 3 - Poor communication     60
# 4 - Poor organisation      57
# Outlier                    48
# Name: topic_desc, dtype: int64

# %%
det_final.to_csv('detractor_table.csv')

# %% [markdown]
# # Intertopic Distance Map

# %%
topic_model_detra.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ced01617-e81e-4ac4-892c-766c84ccf60a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ced01617-e81e-4ac4-892c-766c84ccf60a")) {                    Plotly.newPlot(                        "ced01617-e81e-4ac4-892c-766c84ccf60a",                        [{"customdata":[[0,"took month | process took | medical record | way long | took long",235],[1,"customer service | felt like | bait switch | customer experience | experience great",180],[2,"text email | phone email | email text | email phone | text message",141],[3,"lack communication | response communication | slow response | communication lack | response time",49],[4,"took month | half birthday | account debited | payment info | month finalize",46]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[235,180,141,49,46],"sizemode":"area","sizeref":0.146875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.3755953311920166,3.3696248531341553,2.9833922386169434,3.6960248947143555,2.5649893283843994],"xaxis":"x","y":[7.90185546875,8.713175773620605,6.889152526855469,6.611701488494873,7.969166278839111],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666 ...

# %% [markdown]
# # Topic-word Score Distribution

# %%
topic_model_detra.visualize_barchart(top_n_topics=20, n_words =10, width = 400, height = 500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="40d9a9a6-30ab-479d-ac2b-0e1aeae76718" class="plotly-graph-div" style="height:1000px; width:1600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40d9a9a6-30ab-479d-ac2b-0e1aeae76718")) {                    Plotly.newPlot(                        "40d9a9a6-30ab-479d-ac2b-0e1aeae76718",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006180834917214969,0.006375977928706152,0.008888587481486663,0.009108539898151644,0.00977744622963533,0.011180884383439579,0.011620615211815514,0.015204098434704192,0.018821340878783788,0.01984784452056048],"y":["felt like  ","pacific life  ","long process  ","took way long  ","took way  ","took long  ","way long  ","medical record  ","process took  ","took month  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.004431024171844428,0.00515994560640713,0.00515994560640713,0.005259861064982194,0.005267550330565609,0.005391796897705768,0.006078061662318719,0.00825591297025141,0.008899229967467889,0.0111251895588435],"y":["monthly premium  ","good experience  ","initial quote  ","long time  ","original quote  ","experience great  ","customer experience  ","bait switch  ","felt like  ","customer service  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.005142792935413438,0.005293785825678284,0.005360832727210101,0.005512017810822613,0.005800374347975354,0.005921334476112131,0.009649498908978179,0.009921632059480703,0.010076941539417128,0.010866528068735835],"y":["multiple day  ","different people  ","pacific life  ","poor communication  ","received email  ","text message  ","email phone  ","email text  ","phone email  ","text email  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.02296917214022187,0.027875068902540087,0.027875068902540087,0.029407226746739106,0.029407226746739106,0.03891804547907783,0.04018232306294441,0.04181260335381013,0.04181260335381013,0.04834156980218098],"y":["poor communication  ","proper communication  ","wait time  ","delay processing  ","slow response communication  ","response time  ","communication lack  ","slow response  ","response communication  ","lack communication  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.009298519395711288,0.009298519395711288,0.009298519395711288,0.009298519395711288,0.009298519395711288,0.012305825498166272,0.013221080199740321,0.013221080199740321,0.019965440395270314,0.021230161371045338],"y":["coverage took  ","interim coverage  ","payment date  ","pay higher  ","fault company  ","month finalize  ","payment info  ","account debited  ","half birthday  ","took month  "],"type":"bar","xaxis":"x5","yaxis":"y5"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333 ...

# %% [markdown]
# # Trends

# %%
year_data = np.array(det['year'])

# %%
topics_over_time_detra = topic_model_detra.topics_over_time(det_arr, year_data, global_tuning=True,evolution_tuning=True)
# Out:
# 6it [00:01,  4.25it/s]

# %%
topics_over_time = topic_model_detra.topics_over_time(det_arr, year_data, datetime_format="%b=M%Y")
# Out:
# 6it [00:00, 11.58it/s]

# %%
topic_model_detra.visualize_topics_over_time(topics_over_time_detra, width =1250 , height = 500)   # top_n_topics=20
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d8e6f35f-8999-488c-a15d-a66ec9db4c2b" class="plotly-graph-div" style="height:500px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8e6f35f-8999-488c-a15d-a66ec9db4c2b")) {                    Plotly.newPlot(                        "d8e6f35f-8999-488c-a15d-a66ec9db4c2b",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: process took, took long, zip code finally, miraculously informed, liked updated","<b>Topic 0</b><br>Words: took long, process took, took month, doctor office, received letter","<b>Topic 0</b><br>Words: process took, took way, took long, way long, took way long","<b>Topic 0</b><br>Words: way long, process took, took way long, took way, felt like","<b>Topic 0</b><br>Words: process took, took long, pacific life, long process, health class","<b>Topic 0</b><br>Words: insurer redo, wrong insurer redo, wrong insurer, felt like, local agent instead"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_took month_process took_medical record...","x":[2017,2018,2019,2020,2021,2022],"y":[15,42,50,59,54,15],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: instead annual, final price, want recommend, original quote, underwriting process","<b>Topic 1</b><br>Words: higher price, life second, rate shown, easy process, provide clear guidance","<b>Topic 1</b><br>Words: bait switch, felt like, timely fashion, enrollment process, rate quoted","<b>Topic 1</b><br>Words: customer service, experience great, felt like, bait switch, customer experience","<b>Topic 1</b><br>Words: customer service, bait switch, long time, higher original, higher expected","<b>Topic 1</b><br>Words: felt like, customer service, matter fact tell, customer service supervisor, product promised"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_customer service_felt like_bait switch...","x":[2017,2018,2019,2020,2021,2022],"y":[12,16,25,59,46,22],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: follow process, covered prior, given incorrect email, step going, answered website","<b>Topic 2</b><br>Words: phone email, email text, email phone, rate approved, ask corrected multiple","<b>Topic 2</b><br>Words: need know, asked update, long process, phone email, feel like","<b>Topic 2</b><br>Words: email text, set aside, cancel soon, work company, received email","<b>Topic 2</b><br>Words: customer service, speaking person, william penn, data entry, told application","<b>Topic 2</b><br>Words: poor communication, medical information, different people, email phone, data entry"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_text email_phone email_email text_emai...","x":[2017,2018,2019,2020,2021,2022],"y":[14,16,27,35,27,22],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: need let, underwritten great, completely unorganized unresponsive, completely unorganized, response time changed","<b>Topic 3</b><br>Words: horribly slow, experience communication, consistent point person, response communication coordinated, providing clear","<b>Topic 3</b><br>Words: knowledge miscommunication caused, lack knowledge, caused second, excessive intrusive, painfully slow uncoordinated","<b>Topic 3</b><br>Words: wait time, slow response, response communication, lack communication, response time","<b>Topic 3</b><br>Words: zero communication initial, substantial delay processing, lead substantial, liked faster, attention amateur","<b>Topic 3</b><br>Words: trouble company, really slow, fact called, forth clarity timeline, called opposite"],"marker":{"color":"#F0E442"},"mode":"lines","name":"3_lack communication_response communicat...","x":[2017,2018,2019,2020,2021,2022],"y":[7,7,5,19,8,3],"type":"scatter"},{"hoverinfo" ...

# %%
topic_list = []
words_list = []
freq_list = []
time_list = []
name_list = []
for i in topics_over_time_detra.Topic:
  topic_list.append(i)

for i in topics_over_time_detra.Words:
  words_list.append(i)

for i in topics_over_time_detra.Frequency:
  freq_list.append(i)

for i in topics_over_time_detra.Timestamp:
  time_list.append(i)

for i in topics_over_time_detra.Name:
  name_list.append(i)

# %%
data = {
    "Topic": topic_list,
    "Words": words_list,
    "Frequency": freq_list,
    "Timestamp": time_list,
    "Name": name_list}

df = pd.DataFrame(data)
df.head()

df = df[df['Topic'] != -1].copy()

a = df.groupby('Timestamp')['Frequency'].agg('sum')
b = pd.DataFrame(a)
b.head()
# Out:
#            Frequency
# Timestamp
# 2017              52
# 2018              87
# 2019             116
# 2020             183
# 2021             147

# %%
df3=pd.merge(df,b, how='left', on = 'Timestamp')
df3.head()
# Out:
#    Topic                                              Words  Frequency_x  \
# 0      0  process took, took long, zip code finally, mir...           15
# 1      1  instead annual, final price, want recommend, o...           12
# 2      2  follow process, covered prior, given incorrect...           14
# 3      3  need let, underwritten great, completely unorg...            7
# 4      4  genius initial access, tired dealing issue, is...            4
#
#    Timestamp                                         Name  Frequency_y
# 0       2017  0_took month_process took_medical record...           52
# 1       2017  1_customer service_felt like_bait switch...           52
# 2       2017  2_text email_phone email_email text_emai...           52
# 3       2017  3_lack communication_response communicat...           52
# 4       2017  4_took month_half birthday_account debit...           52

# %%
df3.Frequency_y.value_counts()
# Out:
# 52     5
# 87     5
# 116    5
# 183    5
# 147    5
# 66     5
# Name: Frequency_y, dtype: int64

# %%
df3 = df3.rename(columns={"Frequency_x": "Frequency", "Frequency_y": "Total"})

# %%
df3['Ratio'] = df3['Frequency']/df3['Total']
df3.head()
# Out:
#    Topic                                              Words  Frequency  \
# 0      0  process took, took long, zip code finally, mir...         15
# 1      1  instead annual, final price, want recommend, o...         12
# 2      2  follow process, covered prior, given incorrect...         14
# 3      3  need let, underwritten great, completely unorg...          7
# 4      4  genius initial access, tired dealing issue, is...          4
#
#    Timestamp                                         Name  Total     Ratio
# 0       2017  0_took month_process took_medical record...     52  0.288462
# 1       2017  1_customer service_felt like_bait switch...     52  0.230769
# 2       2017  2_text email_phone email_email text_emai...     52  0.269231
# 3       2017  3_lack communication_response communicat...     52  0.134615
# 4       2017  4_took month_half birthday_account debit...     52  0.076923

# %%
df3 = df3[df3['Topic'] >= 0].copy()

# %%
import seaborn as sns
from matplotlib.pyplot import figure
import matplotlib.ticker as ticker

# %%
# sns.set_palette("pastel")
sns.set(rc={'figure.figsize':(15,10)}, style='white')

# figure(figsize=(15, 10), dpi=80)

ax = sns.lineplot(x='Timestamp', y='Ratio', hue='Topic', 
             data=df3, palette='muted', style='Topic',markers= ["X", "o","<", "v","p"],  dashes=False)
ax.set_ylabel('Proportion of topics', fontsize=13)
ax.set_xlabel('Year', fontsize=13)
ax.set_ylim(0, 0.5)
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

plt.legend(loc='upper right', labels=['0 - Long processes', '1 - High quotes', '2 - Excessive contact', '3 - Poor communication', '4 - Poor organisation'])
plt.title("Trends of Topic Proportions over Years - Detractors", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Trends of Topic Proportions over Years - Detractors')

# %% [markdown]
# ## Monthly Trend

# %%
det_df = pd.DataFrame({'topic': topics, 'doc_cleaned': det_clean1, 'doc_raw': det["verbatim"], 
                            'year': det['year'],
                            'year-month': det['year-month']})
topic_perc = det_df.groupby(['topic', 'year']).size().groupby(['year']).apply(lambda x: (x/x.sum()))
topic_perc = pd.DataFrame(topic_perc).reset_index().rename(columns={0: "Ratio"})

# %%
det_df.topic.value_counts()
det_df = det_df[det_df["topic"]!=-1]

# %%
topic_perc = det_df.groupby(['topic', 'year-month']).size().groupby(['year-month']).apply(lambda x: (x/x.sum()))
topic_perc = pd.DataFrame(topic_perc).reset_index().rename(columns={0: "Ratio"})
topic_perc['year-month'] = pd.to_datetime(topic_perc['year-month']).dt.strftime('%Y-%m')
topic_perc = topic_perc.sort_values(by = ["year-month"])

# %%
import matplotlib.ticker as ticker

# %%
# sns.set_palette("pastel")
sns.set(rc={'figure.figsize':(15,10)}, style='white')

# figure(figsize=(15, 10), dpi=80)

ax = sns.lineplot(x='year-month', y='Ratio', hue='topic', 
             data=topic_perc, palette='muted', style='topic',markers= ["X", "o","<", "v","p"],  dashes=False)
ax.set_ylabel('Proportion of topics', fontsize=13)
ax.set_xlabel('Year', fontsize=13)
ax.set_ylim(0, 1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(base=3))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

plt.xticks(rotation=45)

plt.legend(loc='upper right', labels=['0 - Long processes', '1 - High quotes', '2 - Excessive contact', '3 - Poor communication', '4 - Poor organisation'])
plt.title("Trends of Topic Proportions over Months - Detractors", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Trends of Topic Proportions over Months - Detractors')

# %% [markdown]
# # New Section
