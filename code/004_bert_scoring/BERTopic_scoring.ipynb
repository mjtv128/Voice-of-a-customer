# %% [markdown]
# #Importing libraries and initial config

# %% [markdown]
# ## Libraries

# %%
# !pip install contractions bertopic #joblib==1.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: contractions in /usr/local/lib/python3.9/dist-packages (0.1.73)
# Requirement already satisfied: bertopic in /usr/local/lib/python3.9/dist-packages (0.14.1)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.9/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.9/dist-packages (from bertopic) (0.8.29)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.1.3)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (0.5.3)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.27.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0+cu118)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.13.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.97)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.9/dist-packages (from textsearch>=0.0.21->contractions) (2.0.0)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.9/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.8)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
### Importing necessary libraries
import os
import pandas as pd
import numpy as np
import nltk
import string
import re
#stopwords
from nltk.corpus import stopwords
#tokenizer
from nltk.tokenize import RegexpTokenizer
#lemmatizer
from nltk.stem import WordNetLemmatizer
#Stemmer
from nltk.stem.porter import PorterStemmer

#contractions
import contractions

from bertopic import BERTopic

#gensims
import gensim
from gensim import models
from gensim.utils import simple_preprocess

# colab
from google.colab import auth
from google.cloud import bigquery

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')

pd.set_option("display.max_columns", 100, "display.max_columns", 50)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Authentication

# %%
# authenticate colab to read from bigquery
auth.authenticate_user()

proj_name = 'pg-duke-student-capstone-v1'
proj_num = '545682952716'
proj_id =   'pg-duke-student-capstone-v1'
client = bigquery.Client(project=proj_id)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Config

# %%
# add all global vars here
# vintage = "2023-03"

# specify input path here - one directory above the directory where input csvs are stored
inp_path = "/content/drive/Shareddrives/DukeCapstone/data/Test CSVs for scoring/"

# specify file names for the nps and csat files
nps_inp_file = "NPS March 2023 all sends.csv"
csat_inp_file = "CSAT March 2023 all sends.csv"

# specify path where model checkpoints are stored here
inp_path_chkpts = "/content/drive/Shareddrives/DukeCapstone/results/Model Checkpoints/"

# specify all model checkpoint names here
prom_chkpt = "promoters_checkpoint"
det_chkpt = "det_checkpoint"
passive_chkpt = "passive_checkpoint"
csat_chkpt = "csat_checkpoint"

# specify input path for previously scored comments
inp_scored_path = "/content/drive/Shareddrives/DukeCapstone/results/Final saved data/"

scored_inp_file  = "all_outputs_scored.csv"

# %%
stop_words = stopwords.words('english')

stop_words.extend(['from', 'subject', 'use', 'policygenius', 'policy', 'genius','insurance', "pg", 'none', 'na', "able", "already", "also",
                   "was", "were", "thus", "although", "always", "bc", "because", "definitely", "could", "couldnt", 'would', "wouldnt", "wasy", "grear",
                   "aving","nope", "goo","lol","nah","hiccup", "imani","like"])

# %%
# add all functions here
def preprocess(text_col):
    """This function will apply NLP preprocessing lambda functions over a pandas series such as df['text'].
       These functions include converting text to lowercase, removing emojis, expanding contractions, removing punctuation,
       removing numbers, removing stopwords, lemmatization, etc."""
    
    # convert to lowercase
    text_col = text_col.apply(lambda x: ' '.join([w.lower() for w in x.split('/')]))
    
    # remove emojis
    #text_col = text_col.apply(lambda x: demoji.replace(x, ""))
    
    # expand contractions  
    text_col = text_col.apply(lambda x: ' '.join([contractions.fix(word) for word in x.split()]))

    # remove punctuation
    text_col = text_col.apply(lambda x: ''.join([i for i in x if i not in string.punctuation]))
    
    # remove numbers
    text_col = text_col.apply(lambda x: ' '.join(re.sub("[^a-zA-Z]+", " ", x).split()))

    # remove stopwords
    stopwords = [sw for sw in stop_words if sw not in ['not', 'no']]
    text_col = text_col.apply(lambda x: ' '.join([w for w in x.split() if w not in stopwords]))

    # lemmatization
    text_col = text_col.apply(lambda x: ' '.join([WordNetLemmatizer().lemmatize(w) for w in x.split()]))

    # stemming
    #from nltk.stem import PorterStemmer
    #text_col = text_col.apply(lambda x: ' '.join([PorterStemmer().stem(w) for w in x.split()]))

    # remove short words
    text_col = text_col.apply(lambda x: ' '.join([w.strip() for w in x.split() if len(w.strip()) >= 3]))

    return text_col

# %% [markdown]
# # Data Ingestion

# %%
# read in data to be scored
df_nps = pd.read_csv(os.path.join(inp_path,nps_inp_file))
df_csat = pd.read_csv(os.path.join(inp_path,csat_inp_file))

# %%
display(df_nps.head())
display(df_csat.head())
# Out:
#    Survey Request ID Survey Request Created At Survey Request Dispatch At  \
# 0         3840465071       2023-03-01 12:44:52        2023-03-01 12:44:52
# 1         3840466716       2023-03-01 12:45:57        2023-03-01 12:45:57
# 2         3840467446       2023-03-01 12:46:26        2023-03-01 12:46:26
# 3         3840467868       2023-03-01 12:46:51        2023-03-01 12:46:51
# 4         3840471396       2023-03-01 12:48:52        2023-03-01 12:48:52
#
#     Person ID    Person Created At  Person Email  Person Name Latest Event  \
# 0  1319481689  2023-03-01 12:44:52           NaN          NaN     surveyed
# 1  1319481904  2023-03-01 12:45:57           NaN          NaN     surveyed
# 2  1319482023  2023-03-01 12:46:26           NaN          NaN     surveyed
# 3  1319482086  2023-03-01 12:46:51           NaN          NaN       opened
# 4  1319482418  2023-03-01 12:48:52           NaN          NaN       opened
#
#   Latest Event Timestamp  Survey Response ID  Survey Response Score  \
# 0    2023-03-01 12:44:54                 NaN                    NaN
# 1    2023-03-01 12:45:58                 NaN                    NaN
# 2    2023-03-01 12:46:27                 NaN                    NaN
# 3    2023-03-02 14:06:40                 NaN                    NaN
# 4    2023-03-01 17:19:45                 NaN                    NaN
#
#   Survey Response Comment Survey Response Created At  Survey Response Notes  \
# 0                     NaN                        NaN                    NaN
# 1                     NaN                        NaN                    NaN
# 2                     NaN                        NaN                    NaN
# 3                     NaN                        NaN                    NaN
# 4                     NaN                        NaN                    NaN
#
#    Survey Response Tags  Import ID  Import Size  Import Created At  \
# 0                   NaN        NaN          NaN                NaN
# 1                   NaN        NaN          NaN                NaN
# 2                   NaN        NaN          NaN                NaN
# 3                   NaN        NaN          NaN                NaN
# 4                   NaN        NaN          NaN                NaN
#
#    Import Dispatched At  API Channel  application_id         assignee_name  \
# 0                   NaN  Yes   Email         6283736  Customer_Engagement_
# 1                   NaN  Yes   Email         6167246          Keenan Nessl
# 2                   NaN  Yes   Email         6303816     Stephanie Sanchez
# 3                   NaN  Yes   Email         6299880  Customer_Engagement_
# 4                   NaN  Yes   Email         6302514  Customer_Engagement_
#
#    Browser                 conversation_id  Country  customer_id  \
# 0      NaN  8b624ce0-97a4-4a06-881b-766c2d      NaN     64189460
# 1      NaN  2041bd09-edf5-4f78-af02-dd6193      NaN     63891199
# 2      NaN  9afbc723-9d9c-4fc3-b5e0-d2717e      NaN     64233245
# 3      NaN  c2ce5b57-544c-45de-a53b-6624d2      NaN     64225358
# 4      NaN  ed7c306d-1798-4b6c-8fc1-ce9adc      NaN     64230716
#
#    Delighted Source  Device Type  \
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
#
#                                   internal_case_tags  Operating System  Page  \
# 0  ["CST", "Umbrella Only", "spousal", "Manual Ca...               NaN   NaN
# 1  ["EST", "Umbrella Only", "spousal", "Action: A...               NaN   NaN
# 2  ["Action: Reply to email", "EST", "Umbrella On...               NaN   NaN
# 3  ["CST", "Umbrella Only", "spousal", "Manual Ca...               NaN   NaN
# 4  ["EST", "Umbrella Only", "spousal", "Manual Ca...               NaN   NaN
#
#    Page URL  product product_type  purchase_location  Referrer Site  \
# 0       NaN      NaN         life                NaN            NaN
# 1       NaN      NaN         life                NaN            NaN
# 2       NaN      NaN         life                NaN            NaN
# 3       NaN      NaN         life                NaN            NaN
# 4       NaN      NaN         life                NaN            NaN
#
#    Referrer URL  survey_origin  ticket_id  ticket_tags  ticket_url  \
# 0           NaN            NaN        NaN          NaN         NaN
# 1           NaN            NaN        NaN          NaN         NaN
# 2           NaN            NaN        NaN          NaN         NaN
# 3           NaN            NaN        NaN          NaN         NaN
# 4           NaN            NaN        NaN          NaN         NaN
#
#    ticket_via  zendesk_requester_id  zendesk_ticket_id
# 0         NaN                   NaN                NaN
# 1         NaN                   NaN                NaN
# 2         NaN                   NaN                NaN
# 3         NaN                   NaN                NaN
# 4         NaN                   NaN                NaN
#    Survey Request ID Survey Request Created At Survey Request Dispatch At  \
# 0         3839106812            2/28/2023 6:28              3/1/2023 6:28
# 1         3839131418            2/28/2023 6:52              3/1/2023 6:52
# 2         3839172169            2/28/2023 7:23              3/1/2023 7:23
# 3         3839175854            2/28/2023 7:26              3/1/2023 7:26
# 4         3839176823            2/28/2023 7:27              3/1/2023 7:27
#
#     Person ID Person Created At  Person Email  Person Name Latest Event  \
# 0  1318823178    2/28/2023 6:28           NaN          NaN       opened
# 1  1318831382    2/28/2023 6:52           NaN          NaN   suppressed
# 2  1318848721    2/28/2023 7:23           NaN          NaN   suppressed
# 3  1318850739    2/28/2023 7:26           NaN          NaN     surveyed
# 4  1318851030    2/28/2023 7:27           NaN          NaN     surveyed
#
#   Latest Event Timestamp  Survey Response ID  Survey Response Score  \
# 0          3/1/2023 6:28                 NaN                    NaN
# 1          3/1/2023 6:53                 NaN                    NaN
# 2          3/1/2023 7:23                 NaN                    NaN
# 3          3/1/2023 7:26                 NaN                    NaN
# 4          3/1/2023 7:27                 NaN                    NaN
#
#   Survey Response Comment Survey Response Created At  Survey Response Notes  \
# 0                     NaN                        NaN                    NaN
# 1                     NaN                        NaN                    NaN
# 2                     NaN                        NaN                    NaN
# 3                     NaN                        NaN                    NaN
# 4                     NaN                        NaN                    NaN
#
#    Survey Response Tags  Import ID  Import Size  Import Created At  \
# 0                   NaN        NaN          NaN                NaN
# 1                   NaN        NaN          NaN                NaN
# 2                   NaN        NaN          NaN                NaN
# 3                   NaN        NaN          NaN                NaN
# 4                   NaN        NaN          NaN                NaN
#
#    Import Dispatched At  API Channel  application_id  assignee_name  \
# 0                   NaN  Yes   Email         6017092            NaN
# 1                   NaN  Yes   Email         5983604            NaN
# 2                   NaN  Yes   Email         5403362            NaN
# 3                   NaN  Yes   Email         6308995            NaN
# 4                   NaN  Yes   Email         6300749            NaN
#
#                   conversation_id  customer_id Delighted Browser  \
# 0  880749b3-0588-4a16-9a3f-833696     53679412               NaN
# 1  1deb66cd-3e25-42e8-96ff-a47524     63398547               NaN
# 2  4b383ea6-eb1a-4aaa-b559-cf86db     61931594               NaN
# 3  ed6f5198-e06f-4e01-b688-726905     64243154               NaN
# 4  7aa36f8f-14d5-40d7-9d39-54534b     64227157               NaN
#
#   Delighted Device Type Delighted Operating System Delighted Source  \
# 0                   NaN                        NaN            Email
# 1                   NaN                        NaN            Email
# 2                   NaN                        NaN            Email
# 3                   NaN                        NaN            Email
# 4                   NaN                        NaN            Email
#
#    internal_case_tags       lcs_prior_to_withdrawn  \
# 0                 NaN  application_in_underwriting
# 1                 NaN  application_in_underwriting
# 2                 NaN        application_requested
# 3                 NaN        application_requested
# 4                 NaN      application_not_started
#
#                    withdrawn_lifecycle_stage  \
# 0  underwriting_application_closed_withdrawn
# 1  underwriting_application_closed_withdrawn
# 2                                  withdrawn
# 3                                  withdrawn
# 4                                  withdrawn
#
#    Additional Question: Thanks for your response. Please tell us a bit more about how we could improve. (ID: text_ZH0ENW)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# read in previous scored data
df_scored_prev = pd.read_csv(os.path.join(inp_scored_path,scored_inp_file))

df_scored_prev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16745 entries, 0 to 16744
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   comment      16724 non-null  object
#  1   group        16745 non-null  object
#  2   topic        16745 non-null  int64
#  3   topic_desc   16745 non-null  object
#  4   top_n_words  16745 non-null  object
#  5   date         15615 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 785.0+ KB

# %% [markdown]
# #Data Pre-processing

# %%
# remove all records with null comments for nps
df_nps_notnull = df_nps.dropna(subset=['Survey Response Comment'])

# checking for duplicates for nps
display(df_nps_notnull.loc[df_nps_notnull.duplicated(subset=['Survey Response ID'], keep=False)])
# Out:
# Empty DataFrame
# Columns: [Survey Request ID, Survey Request Created At, Survey Request Dispatch At, Person ID, Person Created At, Person Email, Person Name, Latest Event, Latest Event Timestamp, Survey Response ID, Survey Response Score, Survey Response Comment, Survey Response Created At, Survey Response Notes, Survey Response Tags, Import ID, Import Size, Import Created At, Import Dispatched At, API, Channel, application_id, assignee_name, Browser, conversation_id, Country, customer_id, Delighted Source, Device Type, internal_case_tags, Operating System, Page, Page URL, product, product_type, purchase_location, Referrer Site, Referrer URL, survey_origin, ticket_id, ticket_tags, ticket_url, ticket_via, zendesk_requester_id, zendesk_ticket_id]
# Index: []

# %%
# remove all records with null comments for csat
df_csat_notnull = df_csat.dropna(subset=['Survey Response Comment'])

# checking for duplicates for csat
display(df_csat_notnull.loc[df_csat_notnull.duplicated(subset=['Survey Response ID'], keep=False)])
# Out:
# Empty DataFrame
# Columns: [Survey Request ID, Survey Request Created At, Survey Request Dispatch At, Person ID, Person Created At, Person Email, Person Name, Latest Event, Latest Event Timestamp, Survey Response ID, Survey Response Score, Survey Response Comment, Survey Response Created At, Survey Response Notes, Survey Response Tags, Import ID, Import Size, Import Created At, Import Dispatched At, API, Channel, application_id, assignee_name, conversation_id, customer_id, Delighted Browser, Delighted Device Type, Delighted Operating System, Delighted Source, internal_case_tags, lcs_prior_to_withdrawn, withdrawn_lifecycle_stage, Additional Question: Thanks for your response. Please tell us a bit more about how we could improve. (ID: text_ZH0ENW)]
# Index: []

# %%
# parse dates into year, month, day
df_nps_notnull['date'] = pd.to_datetime(df_nps_notnull['Survey Response Created At'])
df_nps_notnull['day'] = df_nps_notnull['date'].dt.day
df_nps_notnull['month'] = df_nps_notnull['date'].dt.month
df_nps_notnull['year'] = df_nps_notnull['date'].dt.year

# create categories for detractors, passives, promoters
df_nps_notnull["score_categorized"] = pd.cut(df_nps_notnull['Survey Response Score'], bins=[-np.inf, 6, 8, 10],
                  labels=["detractor", "passive", "promoter"])

# %%
# parse dates into year, month, day
df_csat_notnull['date'] = pd.to_datetime(df_csat_notnull['Survey Response Created At'])
df_csat_notnull['day'] = df_csat_notnull['date'].dt.day
df_csat_notnull['month'] = df_csat_notnull['date'].dt.month
df_csat_notnull['year'] = df_csat_notnull['date'].dt.year

# %%
# splitting out data into separate dataframes based on score_categorized
df_prom = df_nps_notnull.loc[df_nps_notnull['score_categorized'] == 'promoter'].copy()
df_det = df_nps_notnull.loc[df_nps_notnull['score_categorized'] == 'detractor'].copy()
df_passive = df_nps_notnull.loc[df_nps_notnull['score_categorized'] == 'passive'].copy()

# %%
df_prom_clean = preprocess(df_prom["Survey Response Comment"])
df_det_clean = preprocess(df_det["Survey Response Comment"])
df_passive_clean = preprocess(df_passive["Survey Response Comment"])
df_csat_clean = preprocess(df_csat_notnull["Survey Response Comment"])

# %%
prom_inp_for_bert = np.array(df_prom_clean)
det_inp_for_bert = np.array(df_det_clean)
passive_inp_for_bert = np.array(df_passive_clean)
csat_inp_for_bert = np.array(df_csat_clean)

# %% [markdown]
# #Model Scoring

# %%
# load model checkpoints
prom_model = BERTopic.load(os.path.join(inp_path_chkpts, prom_chkpt))
det_model = BERTopic.load(os.path.join(inp_path_chkpts, det_chkpt))
passive_model = BERTopic.load(os.path.join(inp_path_chkpts, passive_chkpt))
csat_model = BERTopic.load(os.path.join(inp_path_chkpts, csat_chkpt))

# %%
# generate predictions
topics_prom, probs_prom = prom_model.transform(prom_inp_for_bert)
topics_det, probs_det = det_model.transform(det_inp_for_bert)
topics_passive, probs_passive = passive_model.transform(passive_inp_for_bert)
topics_csat, probs_csat = csat_model.transform(csat_inp_for_bert)
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# create a mapping df that stores all unique combinations of topic and topic descriptions
df_mapping = df_scored_prev.drop_duplicates(subset = ["topic","topic_desc","top_n_words"]).sort_values(by=["group","topic"])[["group","topic","topic_desc","top_n_words"]].reset_index()

# %%
# convert into dataframe
results_prom = pd.DataFrame({'comment': df_prom['Survey Response Comment'], 'topic': topics_prom, "date":df_prom["date"], "group":"promoter"})
results_det = pd.DataFrame({'comment': df_det['Survey Response Comment'], 'topic': topics_det, "date":df_det["date"], "group":"detractor"})
results_passive = pd.DataFrame({'comment': df_passive['Survey Response Comment'], 'topic': topics_passive, "date":df_passive["date"], "group":"passive"})
results_csat = pd.DataFrame({'comment': df_csat_notnull['Survey Response Comment'], 'topic': topics_csat, "date":df_csat_notnull["date"], "group":"csat"})

results_all = pd.DataFrame()

for results_df in [results_prom, results_det, results_csat]:
  temp = results_df.merge(df_mapping, how="left",on=["group","topic"])

  if results_all.empty:
    results_all = temp
  else:
    results_all = pd.concat([results_all, temp])

results_all = results_all[["comment", "group","topic","topic_desc","top_n_words","date"]]
results_all.head()
# Out:
#                                               comment      group  topic  \
# 0   Easy process, no hassle, with knowledgeable st...   promoter     -1
# 1   I work in the life insurance industry (and for...   promoter     -1
# 2     Easy to work with\nTimely follw ups and updates   promoter      1
# 3   They stayed on top of everything and helped me...   promoter     -1
# 4                      Great service and coordination   promoter     -1
# 5   I really like the updates received throughout ...   promoter      1
# 6   Very easy experience. Was a better quote than ...   promoter      1
# 7   Friendly and helpful staff. They did a great j...   promoter      0
# 8   Great customer service. Very responsive to our...   promoter      2
# 9         Very good customer service and easy process   promoter     -1
# 10               Thorough and simple. Quick and easy!   promoter      1
# 11  very attentive, very responsive. Stephanie in ...   promoter      2
# 12  The experience was smooth and I got a rate tha...   promoter      1
# 13                               The process was easy   promoter      1
# 14           Very nice to deal with with great prices   promoter      1
# 15  Great service, straight forward and friendly a...   promoter      0
# 16  Communication was top notch and updates were d...   promoter      1
# 17                            Ease of doing business.   promoter      4
# 18  The customer service is outstanding. I am so g...   promoter      0
# 19             Great price and great customer service   promoter      0
# 20  Fast and efficient process, with exceptional c...   promoter      0
# 21  Smooth and simple process for a good rate on l...   promoter     -1
# 22                                 You guys did great   promoter      0
# 23  Met my expectations, always there for question...   promoter     -1
# 24  Easy to work with. Great customer service. Exc...   promoter      0
# 25                                easy and affordable   promoter      1
# 26  Very easy to use. Has been a sponsor of the To...   promoter      5
# 27                   Great service and easy to apply!   promoter      0
# 28  The process was very informative and easy. Goo...   promoter      0
# 29  PolicyGenius was very easy to work with. A goo...   promoter      0
# 30  Policy genius team was easy to work with and h...   promoter     -1
# 31  Staff very friendly and knowledgeable.  Never ...   promoter     -1
# 32  The team I've worked with has been incredibly ...   promoter     -1
# 33                          Great, easy to work with.   promoter      1
# 34  Very streamlined and was easy to shop for best...   promoter      1
# 35                                              great   promoter      0
# 36  Nick and his team have been very easy to work ...   promoter     -1
# 37                                  very easy process   promoter      1
# 38  I provided my intentions to Policygenius, they...   promoter     -1
# 39                                   Great experience   promoter      0
# 40  Prompt, professional, honest, informative, kno...   promoter     -1
# 41  Extremely easy and great support from the serv...   promoter      0
# 42  Very professional  the rep great knowledge  of...   promoter     -1
# 43                             Rates and ease of use.   promoter      1
# 44  This was a very easy process and I got what I ...   promoter     -1
# 45  My transaction with PlolicyGenius was smooth. ...   promoter     -1
# 46                Great customer service and pricing.   promoter      0
# 47  super easy and got my the policy I wanted at a...   promoter      1
# 48  Expert processing of my life insurance applica...   promoter     -1
# 49  If life insurance ever comes up in topic, I wo...   promoter      1
# 50                     Professional and on top of it!   promoter      0
# 51  awesome team....bunch of high-quality professi...   promoter     -1
# 52  Very convenient and quick access to life insur...   promoter      1
# 53            Great customer service and easy to use.   promoter      0
# 54  Easy digital transaction for an uncomfortable ...   promoter     -1
# 55  Very easy to work with.  They were very helpfu...   promoter      0
# 56  A little pushy on moving the process forward. ...   promoter      0
# 57   Quickly response time and very professional team   promoter     -1
# 58  Easy experience plenty of follow up if you’re ...   promoter     -1
# 59                                   Great experience   promoter      0
# 60  I chose this by gaining g information through ...   promoter     -1
# 61            Easy to work with, helpful and friendly   promoter      0
# 62  Staff was very helpful and responsive. Competi...   promoter      2
# 63  Love it! Made shopping and comparing easy and ...   promoter      1
# 64                                  Excellent service   promoter      0
# 65  Very responsive, helpful and kept me posted th...   promoter      2
# 66  Avoid PDF it was a Struggle for Me even after ...   promoter     -1
# 67  The man I spoke with was helpful and courteous...   promoter     -1
# 68  Easy to understand and complete. Super helpful...   promoter      0
# 69  You did a great job considering all of the doc...   promoter     -1
# 70                                          Thank you   promoter     -1
# 71  The staff is very efficient and professional. ...   promoter      0
# 72  Easier process and my prior shopping found no ...   promoter     -1
# 73  Great service , very pleasant associates , cou...   promoter     -1
# 74                    Easy process. Already have reco   promoter      1
# 75  easy to understand and straightforward in cove...   promoter      3
# 76  Already recommended a few people. This was a g...   promoter      1
# 77  People were very helpful and kept me updated ....   promoter     -1
# 78              Great prices and the process was easy   promoter      1
# 79  Good price, efficient proessimg, friendly supp...   promoter      0
# 80  Satisfied with the handling of the policy with...   promoter     -1
# 81                                        They called   promoter      1
# 82                                   Very easy to use   promoter      1
# 83  Very good customer service and very professional.   promoter      0
# 84                                       Easy of use.   promoter      1
# 85  Easy to work with. Great communication. Got me...   promoter      0
# 86      Much easier to navigate than other companies.   promoter     -1
# 87  It was quick and a great life insurance experi...   promoter      0
# 88    Quick easy process. Representatives were great.   promoter     -1
# 89  Great customer service enabling easy shopping ...   promoter     -1
# 90                     Great service and easy to use!   promoter      0
# 91       excellent customer service and response time   promoter     -1
# 92  Your agents were able to find better policy th...   promoter      0
# 93  I only recommend something if asked to.  I'm v...   promoter      3
# 94       Agent was easy going and very knowledgeable.   promoter      0
# 95  The ease of signing up and attentiveness of th...   promoter      1
# 96  Great customer service, quick turn around time...   promoter     -1
# 97  Pleasant policy genius representative. Explain...   promoter      0
# 98            Super easy, super responsive. The best.   promoter      2
# 0                          The process is complicated  detractor      0
# 1   Terrible experience, took months and months to...  detractor      2
# 2   Multiple errors with quote and improper inform...  detractor     -1
# 3   If you change your policy from $300k to $400k ...  detractor     -1
# 4   Transamerica wanted labs repeated for no good ...  detractor     -1
# 5   Great pricing but the experience was very push...  detractor     -1
# 6   It took too long and i had to repeat several d...  detractor     -1
# 7   When the process first started, they had enter...  detractor     -1
# 0   Make the whole process digital. It's a very ba...       csat     -1
# 1   Awful. I was constantly harrassed by emails, a...       csat     -1
# 2   I was promised that my wife would not be conta...       csat     -1
# 3   I don’t guess anything. I found all the questi...       csat     -1
# 4                        Find lower cost insurance...       csat      3
# 5   quit repeating questions and adding extra ques...       csat     -1
# 6   Constant calling at all hours of the day and n...       csat      1
# 7                                   Not waste my time       csat     -1
# 8   After the initial interview I got 3 more phone...       csat     -1
# 9   The website said it was for an instant quote. ...       csat      2
# 10  Nothing came close to what I am currently paying.       csat     -1
# 11  Allow potential customers to fill out everythi...       csat      2
# 12                 Everything was terrific, thank you       csat      0
# 13  Advantageous cost to change from current provi...       csat     -1
# 14  I’m not happy with you guys,,stop sending mess...       csat     -1
# 15                        give me an insurance policy       csat      4
# 16                                           Nothing        csat      4
# 17           Nothing, the experience was outstanding        csat      0
# 18  Give me what I ask for, not your flagship prod...       csat      0
# 19                                            nothing       csat      4
# 20  Nothing that they did.  My situation is just h...       csat      0
# 21  Policygenius should not have asked me to lie o...       csat     -1
# 22  I was soft quoted one price range over the pho...       csat     -1
# 23                  The sales rep was VERY INPATIENT        csat     -1
# 24  Way too aggressive pursuing the lead. I was ca...       csat     -1
# 25  Not request too much medical information when ...       csat      5
# 26              Agent was short and had bad English.        csat      2
# 27                                               STOP       csat     -1
# 28  The agent was short and condescending towards ...       csat      2
# 29             I forgot his name my agent he"s a good       csat      2
# 30  Given me a quote on the type of policy I actua...       csat      2
# 31                            phone and txt harasment       csat     -1
# 32  The agent who I spoke to was very rude and did...       csat      2
# 33  Nothing, Policygenius did fine. We just needed...       csat     -1
# 34  Eric was kind and professional and answered al...       csat      0
# 35             Too many questions, not any results.         csat     -1
# 36  Called at nine am. I sat for a half hour no ca...       csat      1
# 37                                   cheaper policies       csat     -1
# 38                                           Nothing!       csat      4
# 39  Follow up as promised, Send illustrations as p...       csat     -1
# 40  Your website is wasting people's time when aft...       csat     -1
# 41  Communicate with me on a regular basis, about ...       csat     -1
# 42  Less contact after I told you I did not wish t...       csat      1
# 43                     Have more affordable coverage.       csat      3
# 44  I didn’t get any call for the scheduled appoin...       csat     -1
# 45  We did not receive the help we expected.  We w...       csat     -1
# 46  A faster application process would have been h...       csat      0
# 47  Not harass me! Way too many phone calls, texts...       csat      1
# 48                                           Nothing        csat      4
# 49  It's a waste of time. I have much cheaper poli...       csat     -1
# 50  You promise a quick, simple process, but your ...       csat     -1
# 51  You wasted 2 months of my time. Not to mention...       csat      5
# 52  nobody called back to reschedule appointment f...       csat     -1
# 53  Stop calling and emailing every day. I would l...       csat      1
# 54  Quit harassing folks \r\nStop stalking people ...       csat      1
# 55  Provide more information, when potential clien...       csat     -1
# 56                                                  ,       csat      4
# 57          Don’t harass potential customers so much.       csat      0
# 58                             Found what I needed it       csat      3
# 59                              yup  bit agents didnt       csat      2
# 60  Listen.   That's all.   Just listen.   When I ...       csat      1
# 61                   Better flexibility and options!        csat      3
# 62  not much  professional and timely and when I s...       csat     -1
# 63                    Just didn’t get what I was told       csat      4
# 64  I would have bought the insurance if the compa...       csat     -1
# 65  There was confusion on who could do what and a...       csat     -1
#
#                                 topic_desc  \
# 0                                  Outlier
# 1                                  Outlier
# 2               1 - Quick and easy process
# 3                                  Outlier
# 4                                  Outlier
# 5               1 - Quick and easy process
# 6               1 - Quick and easy process
# 7           0 - Excellent customer service
# 8                      2 - Responsive CSRs
# 9                                  Outlier
# 10              1 - Quick and easy process
# 11                     2 - Responsive CSRs
# 12              1 - Quick and easy process
# 13              1 - Quick and easy process
# 14              1 - Quick and easy process
# 15          0 - Excellent customer service
# 16              1 - Quick and easy process
# 17                  4 - Guidance available
# 18          0 - Excellent customer service
# 19          0 - Excellent customer service
# 20          0 - Excellent customer service
# 21                                 Outlier
# 22          0 - Excellent customer service
# 23                                 Outlier
# 24          0 - Excellent customer service
# 25              1 - Quick and easy process
# 26       5 - Recommended by podcasts/radio
# 27          0 - Excellent customer service
# 28          0 - Excellent customer service
# 29          0 - Excellent customer service
# 30                                 Outlier
# 31                                 Outlier
# 32                                 Outlier
# 33              1 - Quick and easy process
# 34              1 - Quick and easy process
# 35          0 - Excellent customer service
# 36                                 Outlier
# 37              1 - Quick and easy process
# 38                                 Outlier
# 39          0 - Excellent customer service
# 40                                 Outlier
# 41          0 - Excellent customer service
# 42                                 Outlier
# 43              1 - Quick and easy process
# 44                                 Outlier
# 45                                 Outlier
# 46          0 - Excellent customer service
# 47              1 - Quick and easy process
# 48                                 Outlier
# 49              1 - Quick and easy process
# 50          0 - Excellent customer service
# 51                                 Outlier
# 52              1 - Quick and easy process
# 53          0 - Excellent customer service
# 54                                 Outlier
# 55          0 - Excellent customer service
# 56          0 - Excellent customer service
# 57                                 Outlier
# 58                                 Outlier
# 59          0 - Excellent customer service
# 60                                 Outlier
# 61          0 - Excellent customer service
# 62                     2 - Responsive CSRs
# 63              1 - Quick and easy process
# 64          0 - Excellent customer service
# 65                     2 - Responsive CSRs
# 66                                 Outlier
# 67                                 Outlier
# 68          0 - Excellent customer service
# 69                                 Outlier
# 70                                 Outlier
# 71          0 - Excellent customer service
# 72                                 Outlier
# 73                                 Outlier
# 74              1 - Quick and easy process
# 75                       3 - Good coverage
# 76              1 - Quick and easy process
# 77                                 Outlier
# 78              1 - Quick and easy process
# 79          0 - Excellent customer service
# 80                                 Outlier
# 81              1 - Quick and easy process
# 82              1 - Quick and easy process
# 83          0 - Excellent customer service
# 84              1 - Quick and easy process
# 85          0 - Excellent customer service
# 86                                 Outlier
# 87          0 - Excellent customer service
# 88                                 Outlier
# 89                                 Outlier
# 90          0 - Excellent customer service
# 91                                 Outlier
# 92          0 - Excellent customer service
# 93                       3 - Good coverage
# 94          0 - Excellent customer service
# 95              1 - Quick and easy process
# 96                                 Outlier
# 97          0 - Excellent customer service
# 98                     2 - Responsive CSRs
# 0                          0 - High quotes
# 1                   2 - Poor communication
# 2                                 Outliers
# 3                                 Outliers
# 4                                 Outliers
# 5                                 Outliers
# 6                                 Outliers
# 7                                 Outliers
# 0                                 Outliers
# 1                                 Outliers
# 2                                 Outliers
# 3                                 Outliers
# 4                          3 - High quotes
# 5                                 Outliers
# 6                    1 - Excessive contact
# 7                                 Outliers
# 8                                 Outliers
# 9   2 - Want online quotes not calls/talks
# 10                                Outliers
# 11  2 - Want online quotes not calls/talks
# 12              0 - Great Customer Service
# 13                                Outliers
# 14                                Outliers
# 15                              4 - Misled
# 16                              4 - Misled
# 17              0 - Great Customer Service
# 18              0 - Great Customer Service
# 19                              4 - Misled
# 20              0 - Great Customer Service
# 21                                Outliers
# 22                                Outliers
# 23                                Outliers
# 24                                Outliers
# 25       5 - Discontent with medical exams
# 26  2 - Want online quotes not calls/talks
# 27                                Outliers
# 28  2 - Want online quotes not calls/talks
# 29  2 - Want online quotes not calls/talks
# 30  2 - Want online quotes not calls/talks
# 31                                Outliers
# 32  2 - Want online quotes not calls/talks
# 33                                Outliers
# 34              0 - Great Customer Service
# 35                                Outliers
# 36                   1 - Excessive contact
# 37                                Outliers
# 38                              4 - Misled
# 39                                Outliers
# 40                                Outliers
# 41                                Outliers
# 42                   1 - Excessive contact
# 43                         3 - High quotes
# 44                                Outliers
# 45                                Outliers
# 46              0 - Great Customer Service
# 47                   1 - Excessive contact
# 48                              4 - Misled
# 49                                Outliers
# 50                                Outliers
# 51       5 - Discontent with medical exams
# 52                                Outliers
# 53                   1 - Excessive contact
# 54                   1 - Excessive contact
# 55                                Outliers
# 56                              4 - Misled
# 57              0 - Great Customer Service
# 58                         3 - High quotes
# 59  2 - Want online quotes not calls/talks
# 60                   1 - Excessive contact
# 61                         3 - High quotes
# 62                                Outliers
# 63                              4 - Misled
# 64                                Outliers
# 65                                Outliers
#
#                                           top_n_words                date
# 0   customer service - process easy - easy process... 2023-03-01 13:29:06
# 1   customer service - process easy - easy process... 2023-03-01 15:40:37
# 2   easy process - process easy - easy easy - quic... 2023-03-01 19:47:06
# 3   customer service - process easy - easy process... 2023-03-02 01:22:51
# 4   customer service - process easy - easy process... 2023-03-01 19:41:09
# 5   easy process - process easy - easy easy - quic... 2023-03-02 19:21:18
# 6   easy process - process easy - easy easy - quic... 2023-03-01 21:14:41
# 7   customer service - great service - great custo... 2023-03-01 20:10:45
# 8   responsive question - helpful responsive - res... 2023-03-02 16:42:59
# 9   customer service - process easy - easy process... 2023-03-06 21:53:14
# 10  easy process - process easy - easy easy - quic... 2023-03-02 18:23:10
# 11  responsive question - helpful responsive - res... 2023-03-04 19:56:29
# 12  easy process - process easy - easy easy - quic... 2023-03-02 22:46:49
# 13  easy process - process easy - easy easy - quic... 2023-03-03 18:58:01
# 14  easy process - process easy - easy easy - quic... 2023-03-03 19:08:33
# 15  customer service - great service - great custo... 2023-03-06 15:04:38
# 16  easy process - process easy - easy easy - quic... 2023-03-06 19:08:39
# 17  every step - step way - ease ease - every step... 2023-03-07 18:13:21
# 18  customer service - great service - great custo... 2023-03-07 19:32:40
# 19  customer service - great service - great custo... 2023-03-07 19:51:57
# 20  customer service - great service - great custo... 2023-03-07 23:40:15
# 21  customer service - process easy - easy process... 2023-03-08 14:51:22
# 22  customer service - great service - great custo... 2023-03-09 21:21:56
# 23  customer service - process easy - easy process... 2023-03-08 21:03:57
# 24  customer service - great service - great custo... 2023-03-08 21:15:28
# 25  easy process - process easy - easy easy - quic... 2023-03-09 11:05:42
